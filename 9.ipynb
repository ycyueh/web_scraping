# %%
# 匯入套件
from bs4 import BeautifulSoup as bs
import requests as req
from pprint import pprint

# %%
# 取得新聞列表
url = "https://www.ptt.cc/bbs/NBA/index.html" 

# 用 requests 的 get 方法把網頁抓下來
res = req.get(url)
# 指定 lxml 作為解析器
soup = bs(res.text,'lxml')
# 建立 list 來放置列表資訊
list_posts = []

# %%
# 清空放置列表資訊的變數
list_posts.clear()

# 取得 列表 的文字與超連結
for a in soup.select('div.r-ent div.title a[href]'):#a中有href屬性的才放入迴圈
    #print(a.get_text())
    # print(a['href'])# 或是 a.get('href') 
    
    # 加入列表資訊
    list_posts.append({
        'title':a.get_text(),
        'link':'https://www.ptt.cc'+a['href']       
    })
pprint(list_posts)
# Out:
# Re: [討論] Bud 和 Holiday 誰是公鹿真正的大腿
# /bbs/NBA/M.1708067191.A.10D.html
# [新聞] 近12年首次替補 湯普森：可選擇賭氣也可
# /bbs/NBA/M.1708067418.A.275.html
# [花邊] 被字母哥捏+推 GGJ:我核心不夠強 這很痛
# /bbs/NBA/M.1708067570.A.295.html
# Re: [討論] Bud 和 Holiday 誰是公鹿真正的大腿
# /bbs/NBA/M.1708072285.A.02A.html
# [情報] 勇士老闆Lacob:我對KT就像對待自己的兒子
# /bbs/NBA/M.1708077997.A.F73.html
# [情報] Kuzma：在湖人的聚光燈下我常背鍋，這對
# /bbs/NBA/M.1708080619.A.48D.html
# [外絮] 勇士老闆夏天主要目標是不繳稅
# /bbs/NBA/M.1708080661.A.B54.html
# Re: [外絮] 勇士老闆夏天主要目標是不繳稅
# /bbs/NBA/M.1708084467.A.F43.html
# Re: [外絮] 勇士老闆夏天主要目標是不繳稅
# /bbs/NBA/M.1708084710.A.A35.html
# [情報] 今日Ayton 出戰20分鐘，5中1得到2分3助4板
# /bbs/NBA/M.1708087157.A.259.html
# [公告] 板規10.1
# /bbs/NBA/M.1669686360.A.504.html
# [情報] 2023-24賽季 例行賽賽程 (一月、二月上半)
# /bbs/NBA/M.1703474570.A.5DA.html
# [公告] 板主投票開始
# /bbs/NBA/M.1707096285.A.0AB.html
# [公告] NBA 板 開始舉辦樂透!
# /bbs/NBA/M.1708061059.A.423.html
# [情報] NBA Standings (Feb. 16, 2024) Pre AS
# /bbs/NBA/M.1708061682.A.F0C.html
# ...

# %%
# 走訪每一個 a link，整合網頁內文
for index, obj in enumerate(list_posts):
    res_ = req.get(obj['link'])
    soup_ = bs(res_.text,'lxml')

    # 去掉 div.article-metaline (作者、標題、時間…等)
    for div in soup_.select('div[class ^= "article-metaline"]'):
        div.decompose()

     # 去掉 div.push (推文: 推、→、噓) (判斷元素是否存在)
    if len(soup_.select('div.push'))>0:#.select 回傳list，可用len判斷是否有此存在 
        for div in soup_.select('div.push'):
            div.decompose()

    if len(soup_.select('div[class = "richcontent"]'))>0:
        for div in soup_.select('div[class = "richcontent"]'):
            div.decompose()

     # 取得實際需要的內容 (類似 JavaScript 的 innerHTML)
    html = soup_.select_one('div#main-container').decode_contents()
    # html = str(soup_.select_one('div#main-content')) # 類似 JavaScript outerHTML
    
    # 預覽列表和內文
    #print(obj['title'])
    #print(obj['link'])
    #print(html)
    #print("=" * 50)
    
    # 整合到列表資訊的變數當中
    list_posts[index]['contents']=html
    
pprint(list_posts)
# Out:
# [{'contents': '\n'
#               '<div class="bbs-screen bbs-content" id="main-content">\n'
#               '先說我是雲球迷，所以只看最簡單的命中率\n'
#               '\n'
#               '截至本場，24.6分，42.3%fg，34.1%3p\n'
#               '\n'
#               '我也不想黑小李，問題是每次公鹿一輸\n'
#               '\n'
#               '下面全部都在檢討老河\n'
#               '\n'
#               '但小李這命中率打的跟龜龜沒兩樣是要怎麼贏\n'
#               '\n'
#               '為了避免我雲過頭，查了一下mvp龜那年\n'
#               '\n'
#               '2016-17，31.6分，42.5%fg，34.3%3p\n'
#               '\n'
#               '不看籃板助攻的話，把名字遮起來有人分得出來誰是誰嗎\n'
#               '\n'
#               '絕殺了一場，我只是在下面回說前47分鐘多進個兩球還需要投絕殺嗎\n'
#               '\n'
#               '下面一堆人說我不懂小李的價值\n'
#               '\n'
#               '有人說假日還在的話是想看季後又被熱火打爆嗎\n'
#               '\n'
#               '現在換成小李連季賽都有問題…\n'
#               '\n'
#               '不過我想字母應該沒差就是，畢竟是他自己選的\n'
#               '\n'
#               '一換小李來他就續約代表他老大也滿意這筆交易\n'
#               '\n'
# ...

# %%
# 清空放置列表資訊的變數
list_posts.clear()

# 起始頁數
init_p = 4000

# 最新頁數
latest_p = 4003
for page in range(init_p,latest_p+1):
    url = f'https://www.ptt.cc/bbs/Lifeismoney/index{page}.html'
    
    res_money = req.get(url)
    soup_money = bs(res_money.text,'lxml')
    
    #print(soup_money)
    
    for a in soup_money.select('div.r-ent > div.title > a[href]'):
        #print(a.get_text())
        #print(a["href"])
        list_posts.append({
            'title':a.get_text(),
            'html':a["href"]
        })

for index,obj in enumerate(list_posts):
    res_contents = req.get('https://www.ptt.cc/'+obj['html'])
    soup_contents = bs(res_contents.text,'lxml')

    for div in soup_contents.select('div[class ^= "article-metaline"]'):
        div.decompose()

    if len(soup_contents.select('div.push')) >0:
        for div in soup_contents.select('div[class = "push"]'):
            div.decompose()

    if len(soup_contents.select('div.richcontent'))>0:
        for div in soup_contents.select('div[class = "richcontent"]'):
            div.decompose()

    for div in soup_contents.select('div#article-polling'):
        div.decompose()

    html = soup_contents.select_one('div#main-content').decode_contents()

    list_posts[index]['contents'] = html
pprint(list_posts)
# Out:
# [{'contents': '\n'
#               '【活動名稱】：2/9 Line 禮物 家樂福/肯德基 20元優惠券\n'
#               '\n'
#               '【廠商名稱】：Line 禮物\n'
#               '\n'
#               '【活動時間】：2024/2/9～2024/2/10\n'
#               '\n'
#               '【活動內容】\n'
#               '\n'
#               '<a href="https://i.imgur.com/MtvrDl5.jpg" rel="noreferrer '
#               'noopener nofollow" '
#               'target="_blank">https://i.imgur.com/MtvrDl5.jpg</a>\n'
#               '\n'
#               '花80元買了家樂福100元好禮即享券\n'
#               '肯德基和美食名店再看看\n'
#               '\n'
#               '祝大家\n'
#               '福運龍來\n'
#               '\n'
#               '--\n'
#               '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 36.227.205.23 (臺灣)\n'
#               '</span><span class="f2">※ 文章網址: <a '
#               'href="https://www.ptt.cc/bbs/Lifeismoney/M.1707456552.A.037.html" '
#               'rel="noreferrer noopener nofollow" '
# ...

# %%
# 清空放置列表資訊的變數
list_posts.clear()

# 起始頁數
init_page = 6503

# 最新頁數
latest_page = 6504

# 在已經知道分頁數的情況下
for page in range(init_page, latest_page + 1):
    
    # 取得新聞列表
    url = f"https://www.ptt.cc/bbs/NBA/index{page}.html" 

    # 用 requests 的 get 方法把網頁抓下來
    res = req.get(url) 

    # 指定 lxml 作為解析器
    soup = bs(res.text, "lxml") 
    
    # 取得 列表 的文字與超連結
    for a in soup.select('div.r-ent div.title a[href]'):
        # 加入列表資訊
        list_posts.append({
            'title': a.get_text(),
            'link': 'https://www.ptt.cc' + a['href']
        })
        
# 走訪每一個 a link，整合網頁內文
for index, obj in enumerate(list_posts):
    res_ = req.get(obj['link'])
    soup_ = bs(res_.text, "lxml")

    # 去掉 div.article-metaline (作者、標題、時間…等)
    for div in soup_.select('div[class^="article-metaline"]'):
        div.decompose()
        
    # 去掉 div.push (推文: 推、→、噓) (判斷去掉元素是否存在)
    if len( soup_.select('div.push') ) > 0:
        for div in soup_.select('div.push'):
            div.decompose()

    # 取得實際需要的內容 (類似 JavaScript 的 innerHTML)
    html = soup_.select_one('div#main-content').decode_contents()

    # 整合到列表資訊的變數當中
    list_posts[index]['html'] = html

        
# 預覽所有結果
pprint(list_posts)
