# %%
'''
參考網頁
[1] Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學
https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/2/
'''

import requests as req
from bs4 import BeautifulSoup as bs
from pprint import pprint #pretty-print:排版list

 # PTT NBA 板
url = "https://www.ptt.cc/bbs/NBA/index.html"

# 用 requests 的 get 方法把網頁抓下來
res = req.get(url)#header:長期取得網站資料，網站可能會檢查

# 指定 lxml 作為解析器
soup = bs(res.text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/NBA/index.html">看板</a>
# <a class="btn" href="/man/NBA/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/NBA/index6514.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/NBA/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">30</span></div>
# <div class="title">
#
# 				(已被p刪除) &lt;LoveDog29&gt; 150 2-2
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">25</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708067191.A.10D.html">Re: [討論] Bud 和 Holiday 誰是公鹿真正的大腿</a>
# </div>
# <div class="meta">
# <div class="author">strmof22</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+Bud+%E5%92%8C+Holiday+%E8%AA%B0%E6%98%AF%E5%85%AC%E9%B9%BF%E7%9C%9F%E6%AD%A3%E7%9A%84%E5%A4%A7%E8%85%BF">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Astrmof22">搜尋看板內 strmof22 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">38</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708067418.A.275.html">[新聞] 近12年首次替補 湯普森：可選擇賭氣也可</a>
# </div>
# <div class="meta">
# <div class="author">dora1024</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%BF%9112%E5%B9%B4%E9%A6%96%E6%AC%A1%E6%9B%BF%E8%A3%9C+%E6%B9%AF%E6%99%AE%E6%A3%AE%EF%BC%9A%E5%8F%AF%E9%81%B8%E6%93%87%E8%B3%AD%E6%B0%A3%E4%B9%9F%E5%8F%AF">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Adora1024">搜尋看板內 dora1024 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">64</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708067570.A.295.html">[花邊] 被字母哥捏+推 GGJ:我核心不夠強 這很痛</a>
# </div>
# <div class="meta">
# <div class="author">usnavyseal</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E8%A2%AB%E5%AD%97%E6%AF%8D%E5%93%A5%E6%8D%8F%2B%E6%8E%A8+GGJ%3A%E6%88%91%E6%A0%B8%E5%BF%83%E4%B8%8D%E5%A4%A0%E5%BC%B7+%E9%80%99%E5%BE%88%E7%97%9B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ausnavyseal">搜尋看板內 usnavyseal 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1669686360.A.504.html">[公告] 板規10.1</a>
# </div>
# <div class="meta">
# <div class="author">EZ78</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8F10.1">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AEZ78">搜尋看板內 EZ78 的文章</a></div>
# </div>
# </div>
# <div class="date">11/29</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">33</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1703474570.A.5DA.html">[情報] 2023-24賽季 例行賽賽程 (一月、二月上半)</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+2023-24%E8%B3%BD%E5%AD%A3+%E4%BE%8B%E8%A1%8C%E8%B3%BD%E8%B3%BD%E7%A8%8B+%28%E4%B8%80%E6%9C%88%E3%80%81%E4%BA%8C%E6%9C%88%E4%B8%8A%E5%8D%8A%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date">12/25</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">10</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1707096285.A.0AB.html">[公告] 板主投票開始</a>
# </div>
# <div class="meta">
# <div class="author">EZ78</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E4%B8%BB%E6%8A%95%E7%A5%A8%E9%96%8B%E5%A7%8B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AEZ78">搜尋看板內 EZ78 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/05</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708061059.A.423.html">[公告] NBA 板 開始舉辦樂透!</a>
# </div>
# <div class="meta">
# <div class="author">ZIDENS</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+NBA+%E6%9D%BF+%E9%96%8B%E5%A7%8B%E8%88%89%E8%BE%A6%E6%A8%82%E9%80%8F%21">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AZIDENS">搜尋看板內 ZIDENS 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">26</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708061682.A.F0C.html">[情報] NBA Standings (Feb. 16, 2024) Pre AS</a>
# </div>
# <div class="meta">
# <div class="author">guardyo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA+Standings+%28Feb.+16%2C+2024%29+Pre+AS">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aguardyo">搜尋看板內 guardyo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# </div>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"85645e11bb73210b","version":"2024.2.0","r":1,"token":"515615eb5fab4c9b91a11e9bf529e6cf","b":1}' defer="" integrity="sha512-euoFGowhlaLqXsPWQ48qSkBSCFs3DPRyiwVu3FjR96cMPx+Fr+gpWRhIafcHwqwCqWS42RZhIudOvEI+Ckf6MA==" src="https://static.cloudflareinsights.com/beacon.min.js/v84a3a4012de94ce1a686ba8c167c359c1696973893317"></script>
# </body>
# </html>

# %%
# 第一個 <a></a>
print(soup.find("a"),'='*50,sep='\n') 

# 全部 <a></a>，此時回傳 list
print(soup.find_all("a"),'='*50,sep='\n') 

# 指定 list 某個元素的 html
print(soup.find_all("a")[2])
# Out:
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# **************************************************
# [<a href="/bbs/" id="logo">批踢踢實業坊</a>, <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>, <a class="right small" href="/about.html">關於我們</a>, <a class="right small" href="/contact.html">聯絡資訊</a>, <a class="btn selected" href="/bbs/NBA/index.html">看板</a>, <a class="btn" href="/man/NBA/index.html">精華區</a>, <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>, <a class="btn wide" href="/bbs/NBA/index6514.html">‹ 上頁</a>, <a class="btn wide disabled">下頁 ›</a>, <a class="btn wide" href="/bbs/NBA/index.html">最新</a>, <a href="/bbs/NBA/M.1708067191.A.10D.html">Re: [討論] Bud 和 Holiday 誰是公鹿真正的大腿</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+Bud+%E5%92%8C+Holiday+%E8%AA%B0%E6%98%AF%E5%85%AC%E9%B9%BF%E7%9C%9F%E6%AD%A3%E7%9A%84%E5%A4%A7%E8%85%BF">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Astrmof22">搜尋看板內 strmof22 的文章</a>, <a href="/bbs/NBA/M.1708067418.A.275.html">[新聞] 近12年首次替補 湯普森：可選擇賭氣也可</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%BF%9112%E5%B9%B4%E9%A6%96%E6%AC%A1%E6%9B%BF%E8%A3%9C+%E6%B9%AF%E6%99%AE%E6%A3%AE%EF%BC%9A%E5%8F%AF%E9%81%B8%E6%93%87%E8%B3%AD%E6%B0%A3%E4%B9%9F%E5%8F%AF">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Adora1024">搜尋看板內 dora1024 的文章</a>, <a href="/bbs/NBA/M.1708067570.A.295.html">[花邊] 被字母哥捏+推 GGJ:我核心不夠強 這很痛</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E8%A2%AB%E5%AD%97%E6%AF%8D%E5%93%A5%E6%8D%8F%2B%E6%8E%A8+GGJ%3A%E6%88%91%E6%A0%B8%E5%BF%83%E4%B8%8D%E5%A4%A0%E5%BC%B7+%E9%80%99%E5%BE%88%E7%97%9B">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Ausnavyseal">搜尋看板內 usnavyseal 的文章</a>, <a href="/bbs/NBA/M.1669686360.A.504.html">[公告] 板規10.1</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8F10.1">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3AEZ78">搜尋看板內 EZ78 的文章</a>, <a href="/bbs/NBA/M.1703474570.A.5DA.html">[情報] 2023-24賽季 例行賽賽程 (一月、二月上半)</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+2023-24%E8%B3%BD%E5%AD%A3+%E4%BE%8B%E8%A1%8C%E8%B3%BD%E8%B3%BD%E7%A8%8B+%28%E4%B8%80%E6%9C%88%E3%80%81%E4%BA%8C%E6%9C%88%E4%B8%8A%E5%8D%8A%29">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a>, <a href="/bbs/NBA/M.1707096285.A.0AB.html">[公告] 板主投票開始</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E4%B8%BB%E6%8A%95%E7%A5%A8%E9%96%8B%E5%A7%8B">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3AEZ78">搜尋看板內 EZ78 的文章</a>, <a href="/bbs/NBA/M.1708061059.A.423.html">[公告] NBA 板 開始舉辦樂透!</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+NBA+%E6%9D%BF+%E9%96%8B%E5%A7%8B%E8%88%89%E8%BE%A6%E6%A8%82%E9%80%8F%21">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3AZIDENS">搜尋看板內 ZIDENS 的文章</a>, <a href="/bbs/NBA/M.1708061682.A.F0C.html">[情報] NBA Standings (Feb. 16, 2024) Pre AS</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA+Standings+%28Feb.+16%2C+2024%29+Pre+AS">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Aguardyo">搜尋看板內 guardyo 的文章</a>]
# ==================================================
# <a class="right small" href="/about.html">關於我們</a>

# %%
# 取得 id 為 logo 的元素
logo = soup.find(id = 'logo')
print(logo)
# 取得所有 div，類別名稱為 r-ent，回傳為 list
posts = soup.find_all('div',class_='r-ent')
print(posts)
# Out:
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# [<div class="r-ent">
# <div class="nrec"><span class="hl f3">30</span></div>
# <div class="title">
#
# 				(已被p刪除) &lt;LoveDog29&gt; 150 2-2
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">25</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708067191.A.10D.html">Re: [討論] Bud 和 Holiday 誰是公鹿真正的大腿</a>
# </div>
# <div class="meta">
# <div class="author">strmof22</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+Bud+%E5%92%8C+Holiday+%E8%AA%B0%E6%98%AF%E5%85%AC%E9%B9%BF%E7%9C%9F%E6%AD%A3%E7%9A%84%E5%A4%A7%E8%85%BF">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Astrmof22">搜尋看板內 strmof22 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">38</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708067418.A.275.html">[新聞] 近12年首次替補 湯普森：可選擇賭氣也可</a>
# </div>
# <div class="meta">
# <div class="author">dora1024</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%BF%9112%E5%B9%B4%E9%A6%96%E6%AC%A1%E6%9B%BF%E8%A3%9C+%E6%B9%AF%E6%99%AE%E6%A3%AE%EF%BC%9A%E5%8F%AF%E9%81%B8%E6%93%87%E8%B3%AD%E6%B0%A3%E4%B9%9F%E5%8F%AF">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Adora1024">搜尋看板內 dora1024 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">64</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708067570.A.295.html">[花邊] 被字母哥捏+推 GGJ:我核心不夠強 這很痛</a>
# </div>
# <div class="meta">
# <div class="author">usnavyseal</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E8%A2%AB%E5%AD%97%E6%AF%8D%E5%93%A5%E6%8D%8F%2B%E6%8E%A8+GGJ%3A%E6%88%91%E6%A0%B8%E5%BF%83%E4%B8%8D%E5%A4%A0%E5%BC%B7+%E9%80%99%E5%BE%88%E7%97%9B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ausnavyseal">搜尋看板內 usnavyseal 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1669686360.A.504.html">[公告] 板規10.1</a>
# </div>
# <div class="meta">
# <div class="author">EZ78</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8F10.1">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AEZ78">搜尋看板內 EZ78 的文章</a></div>
# </div>
# </div>
# <div class="date">11/29</div>
# <div class="mark">!</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">33</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1703474570.A.5DA.html">[情報] 2023-24賽季 例行賽賽程 (一月、二月上半)</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+2023-24%E8%B3%BD%E5%AD%A3+%E4%BE%8B%E8%A1%8C%E8%B3%BD%E8%B3%BD%E7%A8%8B+%28%E4%B8%80%E6%9C%88%E3%80%81%E4%BA%8C%E6%9C%88%E4%B8%8A%E5%8D%8A%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date">12/25</div>
# <div class="mark">M</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">10</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1707096285.A.0AB.html">[公告] 板主投票開始</a>
# </div>
# <div class="meta">
# <div class="author">EZ78</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E4%B8%BB%E6%8A%95%E7%A5%A8%E9%96%8B%E5%A7%8B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AEZ78">搜尋看板內 EZ78 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/05</div>
# <div class="mark">M</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708061059.A.423.html">[公告] NBA 板 開始舉辦樂透!</a>
# </div>
# <div class="meta">
# <div class="author">ZIDENS</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+NBA+%E6%9D%BF+%E9%96%8B%E5%A7%8B%E8%88%89%E8%BE%A6%E6%A8%82%E9%80%8F%21">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AZIDENS">搜尋看板內 ZIDENS 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark">M</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">26</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1708061682.A.F0C.html">[情報] NBA Standings (Feb. 16, 2024) Pre AS</a>
# </div>
# <div class="meta">
# <div class="author">guardyo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA+Standings+%28Feb.+16%2C+2024%29+Pre+AS">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aguardyo">搜尋看板內 guardyo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/16</div>
# <div class="mark"></div>
# </div>
# </div>]

# %%
'''
以下透過 CSS selector 取得元素，
回傳格式為 list
'''
# 輸出 title
print(soup.select_one('title'))

# 輸出 a
print(soup.select('a'))

# 透過 class 名稱取得元素
print(soup.select('a.board'))

# 透過 id 名稱取得元素
print(soup.select_one('#logo'))

# 透過 attribute 取得元素
print(soup.select('a[class="board"]'))
# Out:
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# [<a href="/bbs/" id="logo">批踢踢實業坊</a>, <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>, <a class="right small" href="/about.html">關於我們</a>, <a class="right small" href="/contact.html">聯絡資訊</a>, <a class="btn selected" href="/bbs/NBA/index.html">看板</a>, <a class="btn" href="/man/NBA/index.html">精華區</a>, <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>, <a class="btn wide" href="/bbs/NBA/index6514.html">‹ 上頁</a>, <a class="btn wide disabled">下頁 ›</a>, <a class="btn wide" href="/bbs/NBA/index.html">最新</a>, <a href="/bbs/NBA/M.1708067191.A.10D.html">Re: [討論] Bud 和 Holiday 誰是公鹿真正的大腿</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+Bud+%E5%92%8C+Holiday+%E8%AA%B0%E6%98%AF%E5%85%AC%E9%B9%BF%E7%9C%9F%E6%AD%A3%E7%9A%84%E5%A4%A7%E8%85%BF">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Astrmof22">搜尋看板內 strmof22 的文章</a>, <a href="/bbs/NBA/M.1708067418.A.275.html">[新聞] 近12年首次替補 湯普森：可選擇賭氣也可</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%BF%9112%E5%B9%B4%E9%A6%96%E6%AC%A1%E6%9B%BF%E8%A3%9C+%E6%B9%AF%E6%99%AE%E6%A3%AE%EF%BC%9A%E5%8F%AF%E9%81%B8%E6%93%87%E8%B3%AD%E6%B0%A3%E4%B9%9F%E5%8F%AF">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Adora1024">搜尋看板內 dora1024 的文章</a>, <a href="/bbs/NBA/M.1708067570.A.295.html">[花邊] 被字母哥捏+推 GGJ:我核心不夠強 這很痛</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E8%A2%AB%E5%AD%97%E6%AF%8D%E5%93%A5%E6%8D%8F%2B%E6%8E%A8+GGJ%3A%E6%88%91%E6%A0%B8%E5%BF%83%E4%B8%8D%E5%A4%A0%E5%BC%B7+%E9%80%99%E5%BE%88%E7%97%9B">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Ausnavyseal">搜尋看板內 usnavyseal 的文章</a>, <a href="/bbs/NBA/M.1669686360.A.504.html">[公告] 板規10.1</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8F10.1">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3AEZ78">搜尋看板內 EZ78 的文章</a>, <a href="/bbs/NBA/M.1703474570.A.5DA.html">[情報] 2023-24賽季 例行賽賽程 (一月、二月上半)</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+2023-24%E8%B3%BD%E5%AD%A3+%E4%BE%8B%E8%A1%8C%E8%B3%BD%E8%B3%BD%E7%A8%8B+%28%E4%B8%80%E6%9C%88%E3%80%81%E4%BA%8C%E6%9C%88%E4%B8%8A%E5%8D%8A%29">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a>, <a href="/bbs/NBA/M.1707096285.A.0AB.html">[公告] 板主投票開始</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E4%B8%BB%E6%8A%95%E7%A5%A8%E9%96%8B%E5%A7%8B">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3AEZ78">搜尋看板內 EZ78 的文章</a>, <a href="/bbs/NBA/M.1708061059.A.423.html">[公告] NBA 板 開始舉辦樂透!</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+NBA+%E6%9D%BF+%E9%96%8B%E5%A7%8B%E8%88%89%E8%BE%A6%E6%A8%82%E9%80%8F%21">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3AZIDENS">搜尋看板內 ZIDENS 的文章</a>, <a href="/bbs/NBA/M.1708061682.A.F0C.html">[情報] NBA Standings (Feb. 16, 2024) Pre AS</a>, <a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA+Standings+%28Feb.+16%2C+2024%29+Pre+AS">搜尋同標題文章</a>, <a href="/bbs/NBA/search?q=author%3Aguardyo">搜尋看板內 guardyo 的文章</a>]
# [<a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>]
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# [<a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>]

# %%
# 取得單一節點的文字內容 (select_one 會回傳單一 bs element 物件，select 會回傳 list)
print(soup.select_one('title').get_text())#取得純文字
#print(soup.find_all("a")[2]) #輸出元素
print(soup.select('a')[0].get_text())
# Out:
# 看板 NBA 文章列表 - 批踢踢實業坊
# 批踢踢實業坊

# %%
# 透過迭代取得所有 a 的文字內容
for a in soup.select('a'):
     print(a.get_text())
# Out:
# 批踢踢實業坊
# 看板 NBA
# 關於我們
# 聯絡資訊
# 看板
# 精華區
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# Re: [討論] Bud 和 Holiday 誰是公鹿真正的大腿
# 搜尋同標題文章
# 搜尋看板內 strmof22 的文章
# [新聞] 近12年首次替補 湯普森：可選擇賭氣也可
# 搜尋同標題文章
# 搜尋看板內 dora1024 的文章
# [花邊] 被字母哥捏+推 GGJ:我核心不夠強 這很痛
# 搜尋同標題文章
# 搜尋看板內 usnavyseal 的文章
# [公告] 板規10.1
# 搜尋同標題文章
# 搜尋看板內 EZ78 的文章
# [情報] 2023-24賽季 例行賽賽程 (一月、二月上半)
# 搜尋同標題文章
# 搜尋看板內 laptic 的文章
# [公告] 板主投票開始
# 搜尋同標題文章
# 搜尋看板內 EZ78 的文章
# [公告] NBA 板 開始舉辦樂透!
# 搜尋同標題文章
# 搜尋看板內 ZIDENS 的文章
# [情報] NBA Standings (Feb. 16, 2024) Pre AS
# 搜尋同標題文章
# 搜尋看板內 guardyo 的文章

# %%
# 透過迭代取得所有 a 的屬性 href
for a in soup.select('a'):
    if a.has_attr('href'):
        print(a['href'])
    else:
        print('='*50)
        print(f"連結[{a.get_text()}]沒有href屬性")
        print('='*50)
# Out:
# /bbs/
# /bbs/NBA/index.html
# /about.html
# /contact.html
# /bbs/NBA/index.html
# /man/NBA/index.html
# /bbs/NBA/index1.html
# /bbs/NBA/index6514.html
# ==================================================
# 連結[下頁 ›]沒有href屬性
# ==================================================
# /bbs/NBA/index.html
# /bbs/NBA/M.1708067191.A.10D.html
# /bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+Bud+%E5%92%8C+Holiday+%E8%AA%B0%E6%98%AF%E5%85%AC%E9%B9%BF%E7%9C%9F%E6%AD%A3%E7%9A%84%E5%A4%A7%E8%85%BF
# /bbs/NBA/search?q=author%3Astrmof22
# /bbs/NBA/M.1708067418.A.275.html
# /bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%BF%9112%E5%B9%B4%E9%A6%96%E6%AC%A1%E6%9B%BF%E8%A3%9C+%E6%B9%AF%E6%99%AE%E6%A3%AE%EF%BC%9A%E5%8F%AF%E9%81%B8%E6%93%87%E8%B3%AD%E6%B0%A3%E4%B9%9F%E5%8F%AF
# /bbs/NBA/search?q=author%3Adora1024
# /bbs/NBA/M.1708067570.A.295.html
# /bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E8%A2%AB%E5%AD%97%E6%AF%8D%E5%93%A5%E6%8D%8F%2B%E6%8E%A8+GGJ%3A%E6%88%91%E6%A0%B8%E5%BF%83%E4%B8%8D%E5%A4%A0%E5%BC%B7+%E9%80%99%E5%BE%88%E7%97%9B
# /bbs/NBA/search?q=author%3Ausnavyseal
# /bbs/NBA/M.1669686360.A.504.html
# /bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8F10.1
# /bbs/NBA/search?q=author%3AEZ78
# /bbs/NBA/M.1703474570.A.5DA.html
# /bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+2023-24%E8%B3%BD%E5%AD%A3+%E4%BE%8B%E8%A1%8C%E8%B3%BD%E8%B3%BD%E7%A8%8B+%28%E4%B8%80%E6%9C%88%E3%80%81%E4%BA%8C%E6%9C%88%E4%B8%8A%E5%8D%8A%29
# /bbs/NBA/search?q=author%3Alaptic
# /bbs/NBA/M.1707096285.A.0AB.html
# /bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E4%B8%BB%E6%8A%95%E7%A5%A8%E9%96%8B%E5%A7%8B
# /bbs/NBA/search?q=author%3AEZ78
# /bbs/NBA/M.1708061059.A.423.html
# /bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+NBA+%E6%9D%BF+%E9%96%8B%E5%A7%8B%E8%88%89%E8%BE%A6%E6%A8%82%E9%80%8F%21
# /bbs/NBA/search?q=author%3AZIDENS
# /bbs/NBA/M.1708061682.A.F0C.html
# /bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA+Standings+%28Feb.+16%2C+2024%29+Pre+AS
# /bbs/NBA/search?q=author%3Aguardyo
